# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy
from config import weather_api_key
import requests
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
# for coordinate in coordinates:
#     print(coordinate[0], coordinate[1])

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 629

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=814b8a709d2063b56a9bcec3265ac8d3

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
# for i in range(len(cities)):

#     # Group cities in sets of 50 for logging purposes.
#     if (i % 50 == 0 and i >= 50):
#         set_count += 1
#         record_count = 1
#         time.sleep(60)

#     # Create endpoint URL with each city.
#     city_url = url + "&q=" + cities[i]

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Weather description" : weather_desc
                         
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass


len(city_data)

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | leh
# Processing Record 7 of Set 1 | bredasdorp
# Processing Record 8 of Set 1 | hilo
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | norrtalje
# Processing Record 11 of Set 1 | hurghada
# Processing Record 12 of Set 1 | yzeure
# Processing Record 13 of Set 1 | harper
# Processing Record 14 of Set 1 | vaini
# Processing Record 15 of Set 1 | northam
# Processing Record 16 of Set 1 | kysyl-syr
# Processing Record 17 of Set 1 | lasa
# Processing Record 18 of Set 1 | vanimo
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | huarmey
# Processing Record 21 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 22 of Set 1 | fare
# Processing Record 23 of Set 1 | port hardy
# Processing Record 24 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 1 | portland
# Processing Record 26 of Set 1 | helena
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | boa vista
# Processing Record 29 of Set 1 | merauke
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | san rafael
# Processing Record 34 of Set 1 | qaanaaq
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | mendahara
# City not found. Skipping...
# Processing Record 37 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 1 | jamestown
# Processing Record 39 of Set 1 | new norfolk
# Processing Record 40 of Set 1 | namasuba
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | yerbogachen
# Processing Record 43 of Set 1 | yuncheng
# Processing Record 44 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 45 of Set 1 | mlonggo
# Processing Record 46 of Set 1 | upernavik
# Processing Record 47 of Set 1 | pedernales
# Processing Record 48 of Set 1 | maniitsoq
# Processing Record 49 of Set 1 | leningradskiy
# Processing Record 50 of Set 1 | yellowknife
# Processing Record 1 of Set 2 | namatanai
# Processing Record 2 of Set 2 | souillac
# Processing Record 3 of Set 2 | north augusta
# Processing Record 4 of Set 2 | georgetown
# Processing Record 5 of Set 2 | codrington
# Processing Record 6 of Set 2 | metro
# Processing Record 7 of Set 2 | thompson
# Processing Record 8 of Set 2 | cockburn town
# Processing Record 9 of Set 2 | hovd
# Processing Record 10 of Set 2 | hasaki
# Processing Record 11 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 12 of Set 2 | albemarle
# Processing Record 13 of Set 2 | nanortalik
# Processing Record 14 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | malanje
# Processing Record 17 of Set 2 | ahipara
# Processing Record 18 of Set 2 | norman wells
# Processing Record 19 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 20 of Set 2 | luderitz
# Processing Record 21 of Set 2 | kodiak
# Processing Record 22 of Set 2 | asau
# Processing Record 23 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 2 | upata
# Processing Record 25 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 2 | butaritari
# Processing Record 27 of Set 2 | tuktoyaktuk
# Processing Record 28 of Set 2 | salamiyah
# Processing Record 29 of Set 2 | lompoc
# Processing Record 30 of Set 2 | poya
# Processing Record 31 of Set 2 | chokurdakh
# Processing Record 32 of Set 2 | galiwinku
# City not found. Skipping...
# Processing Record 33 of Set 2 | tiksi
# Processing Record 34 of Set 2 | tres de maio
# Processing Record 35 of Set 2 | la ronge
# Processing Record 36 of Set 2 | pisco
# Processing Record 37 of Set 2 | ardatov
# Processing Record 38 of Set 2 | ola
# Processing Record 39 of Set 2 | panaba
# Processing Record 40 of Set 2 | arraial do cabo
# Processing Record 41 of Set 2 | port elizabeth
# Processing Record 42 of Set 2 | saint-georges
# Processing Record 43 of Set 2 | cherskiy
# Processing Record 44 of Set 2 | barrow
# Processing Record 45 of Set 2 | imbituba
# Processing Record 46 of Set 2 | hobart
# Processing Record 47 of Set 2 | college
# Processing Record 48 of Set 2 | pacific grove
# Processing Record 49 of Set 2 | liuhe
# Processing Record 50 of Set 2 | ossora
# Processing Record 1 of Set 3 | acajutla
# Processing Record 2 of Set 3 | algiers
# Processing Record 3 of Set 3 | vangaindrano
# Processing Record 4 of Set 3 | santa fe
# Processing Record 5 of Set 3 | beloha
# Processing Record 6 of Set 3 | skibbereen
# Processing Record 7 of Set 3 | omboue
# Processing Record 8 of Set 3 | amahai
# Processing Record 9 of Set 3 | wanning
# Processing Record 10 of Set 3 | carnarvon
# Processing Record 11 of Set 3 | puerto carreno
# Processing Record 12 of Set 3 | bethel
# Processing Record 13 of Set 3 | rolla
# Processing Record 14 of Set 3 | agadez
# Processing Record 15 of Set 3 | kavieng
# Processing Record 16 of Set 3 | valdivia
# Processing Record 17 of Set 3 | panguipulli
# Processing Record 18 of Set 3 | sinnar
# Processing Record 19 of Set 3 | waipawa
# Processing Record 20 of Set 3 | lorengau
# Processing Record 21 of Set 3 | dikson
# Processing Record 22 of Set 3 | svetlogorsk
# Processing Record 23 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 3 | alofi
# Processing Record 25 of Set 3 | lavrentiya
# Processing Record 26 of Set 3 | san patricio
# Processing Record 27 of Set 3 | porto novo
# Processing Record 28 of Set 3 | barra do garcas
# Processing Record 29 of Set 3 | bilibino
# Processing Record 30 of Set 3 | paderborn
# Processing Record 31 of Set 3 | penzance
# Processing Record 32 of Set 3 | bereda
# Processing Record 33 of Set 3 | kostomuksha
# Processing Record 34 of Set 3 | ilulissat
# Processing Record 35 of Set 3 | hermanus
# Processing Record 36 of Set 3 | mombetsu
# Processing Record 37 of Set 3 | half moon bay
# Processing Record 38 of Set 3 | bambous virieux
# Processing Record 39 of Set 3 | celestun
# Processing Record 40 of Set 3 | shingu
# Processing Record 41 of Set 3 | srednekolymsk
# Processing Record 42 of Set 3 | roebourne
# Processing Record 43 of Set 3 | saskylakh
# Processing Record 44 of Set 3 | muskegon
# Processing Record 45 of Set 3 | ponta do sol
# Processing Record 46 of Set 3 | puerto ayora
# Processing Record 47 of Set 3 | shizilu
# Processing Record 48 of Set 3 | esperance
# Processing Record 49 of Set 3 | atuona
# Processing Record 50 of Set 3 | finschhafen
# Processing Record 1 of Set 4 | bilma
# Processing Record 2 of Set 4 | shymkent
# Processing Record 3 of Set 4 | genhe
# Processing Record 4 of Set 4 | moranbah
# Processing Record 5 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 4 | okhotsk
# Processing Record 7 of Set 4 | sulangan
# Processing Record 8 of Set 4 | hindoria
# City not found. Skipping...
# Processing Record 9 of Set 4 | hambantota
# Processing Record 10 of Set 4 | cayenne
# Processing Record 11 of Set 4 | ismailia
# Processing Record 12 of Set 4 | lebu
# Processing Record 13 of Set 4 | hamilton
# Processing Record 14 of Set 4 | kruisfontein
# Processing Record 15 of Set 4 | zanesville
# Processing Record 16 of Set 4 | meulaboh
# Processing Record 17 of Set 4 | airai
# Processing Record 18 of Set 4 | agua branca
# Processing Record 19 of Set 4 | ancud
# Processing Record 20 of Set 4 | yamada
# Processing Record 21 of Set 4 | coahuayana
# Processing Record 22 of Set 4 | gangtok
# Processing Record 23 of Set 4 | tikapur
# Processing Record 24 of Set 4 | mar del plata
# Processing Record 25 of Set 4 | tado
# Processing Record 26 of Set 4 | adrar
# Processing Record 27 of Set 4 | kapaa
# Processing Record 28 of Set 4 | bengkulu
# Processing Record 29 of Set 4 | belawan
# Processing Record 30 of Set 4 | salalah
# Processing Record 31 of Set 4 | sorland
# Processing Record 32 of Set 4 | roald
# Processing Record 33 of Set 4 | acari
# Processing Record 34 of Set 4 | loa janan
# Processing Record 35 of Set 4 | cidreira
# Processing Record 36 of Set 4 | katobu
# Processing Record 37 of Set 4 | sitka
# Processing Record 38 of Set 4 | longyearbyen
# Processing Record 39 of Set 4 | marawi
# Processing Record 40 of Set 4 | komsomolskiy
# Processing Record 41 of Set 4 | rocky mountain house
# Processing Record 42 of Set 4 | mokhsogollokh
# Processing Record 43 of Set 4 | nongan
# Processing Record 44 of Set 4 | east london
# Processing Record 45 of Set 4 | moron
# Processing Record 46 of Set 4 | saldanha
# Processing Record 47 of Set 4 | general roca
# Processing Record 48 of Set 4 | bandarbeyla
# Processing Record 49 of Set 4 | borogontsy
# Processing Record 50 of Set 4 | ayan
# Processing Record 1 of Set 5 | fortuna
# Processing Record 2 of Set 5 | kattivakkam
# Processing Record 3 of Set 5 | vitim
# Processing Record 4 of Set 5 | baoshan
# Processing Record 5 of Set 5 | isangel
# Processing Record 6 of Set 5 | maraa
# Processing Record 7 of Set 5 | dingle
# Processing Record 8 of Set 5 | waitati
# Processing Record 9 of Set 5 | raga
# Processing Record 10 of Set 5 | victoria
# Processing Record 11 of Set 5 | festus
# Processing Record 12 of Set 5 | yinchuan
# Processing Record 13 of Set 5 | paamiut
# Processing Record 14 of Set 5 | kesova gora
# Processing Record 15 of Set 5 | felanitx
# Processing Record 16 of Set 5 | khanapur
# Processing Record 17 of Set 5 | sobolevo
# Processing Record 18 of Set 5 | mao
# Processing Record 19 of Set 5 | laguna
# Processing Record 20 of Set 5 | saint-philippe
# Processing Record 21 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 22 of Set 5 | cap malheureux
# Processing Record 23 of Set 5 | mahon
# Processing Record 24 of Set 5 | semey
# Processing Record 25 of Set 5 | tasiilaq
# Processing Record 26 of Set 5 | zhigansk
# Processing Record 27 of Set 5 | mackay
# Processing Record 28 of Set 5 | nikolskoye
# Processing Record 29 of Set 5 | springs
# Processing Record 30 of Set 5 | santa maria
# Processing Record 31 of Set 5 | pangnirtung
# Processing Record 32 of Set 5 | maceio
# Processing Record 33 of Set 5 | borba
# Processing Record 34 of Set 5 | shimoda
# Processing Record 35 of Set 5 | winnemucca
# Processing Record 36 of Set 5 | poum
# Processing Record 37 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 38 of Set 5 | sambava
# Processing Record 39 of Set 5 | carson city
# Processing Record 40 of Set 5 | isla mujeres
# Processing Record 41 of Set 5 | sao jose da coroa grande
# Processing Record 42 of Set 5 | sauda
# Processing Record 43 of Set 5 | daru
# Processing Record 44 of Set 5 | samarai
# Processing Record 45 of Set 5 | port alfred
# Processing Record 46 of Set 5 | biloela
# Processing Record 47 of Set 5 | hobyo
# Processing Record 48 of Set 5 | touros
# Processing Record 49 of Set 5 | palu
# Processing Record 50 of Set 5 | mariakani
# Processing Record 1 of Set 6 | le vauclin
# Processing Record 2 of Set 6 | shawville
# Processing Record 3 of Set 6 | keningau
# Processing Record 4 of Set 6 | castro
# Processing Record 5 of Set 6 | anito
# Processing Record 6 of Set 6 | puerto escondido
# Processing Record 7 of Set 6 | haines junction
# Processing Record 8 of Set 6 | beringovskiy
# Processing Record 9 of Set 6 | ruwi
# Processing Record 10 of Set 6 | torbay
# Processing Record 11 of Set 6 | bubaque
# Processing Record 12 of Set 6 | sao joao da barra
# Processing Record 13 of Set 6 | koulikoro
# Processing Record 14 of Set 6 | porbandar
# Processing Record 15 of Set 6 | funadhoo
# Processing Record 16 of Set 6 | port-cartier
# Processing Record 17 of Set 6 | sao raimundo nonato
# Processing Record 18 of Set 6 | belmonte
# Processing Record 19 of Set 6 | urucara
# Processing Record 20 of Set 6 | muros
# Processing Record 21 of Set 6 | lagos
# Processing Record 22 of Set 6 | grindavik
# Processing Record 23 of Set 6 | yarke pole
# Processing Record 24 of Set 6 | yulara
# Processing Record 25 of Set 6 | sao filipe
# Processing Record 26 of Set 6 | novoagansk
# Processing Record 27 of Set 6 | hami
# Processing Record 28 of Set 6 | ouango
# Processing Record 29 of Set 6 | vardo
# Processing Record 30 of Set 6 | severomorsk
# Processing Record 31 of Set 6 | alto araguaia
# Processing Record 32 of Set 6 | kaitangata
# Processing Record 33 of Set 6 | fairbanks
# Processing Record 34 of Set 6 | kungurtug
# Processing Record 35 of Set 6 | keetmanshoop
# Processing Record 36 of Set 6 | villarrica
# Processing Record 37 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 6 | estacion coahuila
# Processing Record 39 of Set 6 | ulety
# Processing Record 40 of Set 6 | pochutla
# Processing Record 41 of Set 6 | ust-nera
# Processing Record 42 of Set 6 | inuvik
# Processing Record 43 of Set 6 | severo-kurilsk
# Processing Record 44 of Set 6 | dahanu
# Processing Record 45 of Set 6 | darhan
# Processing Record 46 of Set 6 | duma
# Processing Record 47 of Set 6 | oriximina
# Processing Record 48 of Set 6 | karmaskaly
# Processing Record 49 of Set 6 | puro
# Processing Record 50 of Set 6 | aljezur
# Processing Record 1 of Set 7 | rio grande
# Processing Record 2 of Set 7 | uwayl
# City not found. Skipping...
# Processing Record 3 of Set 7 | bandrele
# Processing Record 4 of Set 7 | talnakh
# Processing Record 5 of Set 7 | imeni poliny osipenko
# Processing Record 6 of Set 7 | kemijarvi
# Processing Record 7 of Set 7 | iracoubo
# Processing Record 8 of Set 7 | kedrovyy
# Processing Record 9 of Set 7 | zabol
# Processing Record 10 of Set 7 | road town
# Processing Record 11 of Set 7 | lulea
# Processing Record 12 of Set 7 | mehamn
# Processing Record 13 of Set 7 | saint-medard-en-jalles
# Processing Record 14 of Set 7 | dickinson
# Processing Record 15 of Set 7 | provideniya
# Processing Record 16 of Set 7 | akdepe
# Processing Record 17 of Set 7 | flinders
# Processing Record 18 of Set 7 | sept-iles
# Processing Record 19 of Set 7 | ballina
# Processing Record 20 of Set 7 | banjar
# Processing Record 21 of Set 7 | khani
# Processing Record 22 of Set 7 | sola
# Processing Record 23 of Set 7 | bathsheba
# Processing Record 24 of Set 7 | san quintin
# Processing Record 25 of Set 7 | aklavik
# Processing Record 26 of Set 7 | bocaranga
# City not found. Skipping...
# Processing Record 27 of Set 7 | tessalit
# Processing Record 28 of Set 7 | wahpeton
# Processing Record 29 of Set 7 | constitucion
# Processing Record 30 of Set 7 | narsaq
# Processing Record 31 of Set 7 | ko samui
# Processing Record 32 of Set 7 | fukue
# Processing Record 33 of Set 7 | berlevag
# Processing Record 34 of Set 7 | inta
# Processing Record 35 of Set 7 | rudbar
# Processing Record 36 of Set 7 | kourou
# Processing Record 37 of Set 7 | setermoen
# Processing Record 38 of Set 7 | purpe
# Processing Record 39 of Set 7 | nishihara
# Processing Record 40 of Set 7 | pascagoula
# Processing Record 41 of Set 7 | tumbagaan
# Processing Record 42 of Set 7 | rawlins
# Processing Record 43 of Set 7 | karasburg
# Processing Record 44 of Set 7 | dalvik
# Processing Record 45 of Set 7 | ngunguru
# Processing Record 46 of Set 7 | payo
# Processing Record 47 of Set 7 | hofn
# Processing Record 48 of Set 7 | cabras
# Processing Record 49 of Set 7 | illapel
# Processing Record 50 of Set 7 | ambanja
# Processing Record 1 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 2 of Set 8 | hirara
# Processing Record 3 of Set 8 | xining
# Processing Record 4 of Set 8 | faanui
# Processing Record 5 of Set 8 | chuy
# Processing Record 6 of Set 8 | yei
# Processing Record 7 of Set 8 | macamic
# Processing Record 8 of Set 8 | smoky lake
# Processing Record 9 of Set 8 | tura
# Processing Record 10 of Set 8 | champerico
# Processing Record 11 of Set 8 | matagami
# Processing Record 12 of Set 8 | lata
# Processing Record 13 of Set 8 | jiuquan
# Processing Record 14 of Set 8 | el cobre
# Processing Record 15 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 16 of Set 8 | lapua
# Processing Record 17 of Set 8 | gamba
# Processing Record 18 of Set 8 | ginir
# Processing Record 19 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 8 | hay river
# Processing Record 21 of Set 8 | roma
# Processing Record 22 of Set 8 | nabire
# Processing Record 23 of Set 8 | bonthe
# Processing Record 24 of Set 8 | frontera
# Processing Record 25 of Set 8 | shushenskoye
# Processing Record 26 of Set 8 | vreed en hoop
# City not found. Skipping...
# Processing Record 27 of Set 8 | abu kamal
# Processing Record 28 of Set 8 | veshenskaya
# Processing Record 29 of Set 8 | salisbury
# Processing Record 30 of Set 8 | brae
# Processing Record 31 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 32 of Set 8 | tibacuy
# Processing Record 33 of Set 8 | marigot
# Processing Record 34 of Set 8 | klaksvik
# Processing Record 35 of Set 8 | fond du lac
# Processing Record 36 of Set 8 | cabo san lucas
# Processing Record 37 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 8 | simao
# Processing Record 39 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 8 | quatre cocos
# Processing Record 41 of Set 8 | yumen
# Processing Record 42 of Set 8 | puri
# Processing Record 43 of Set 8 | caravelas
# Processing Record 44 of Set 8 | husavik
# Processing Record 45 of Set 8 | tuatapere
# Processing Record 46 of Set 8 | ilinskiy
# Processing Record 47 of Set 8 | kamenka
# Processing Record 48 of Set 8 | gurupi
# Processing Record 49 of Set 8 | mount gambier
# Processing Record 50 of Set 8 | camacha
# Processing Record 1 of Set 9 | shaowu
# Processing Record 2 of Set 9 | plymouth
# Processing Record 3 of Set 9 | gravdal
# Processing Record 4 of Set 9 | coquimbo
# Processing Record 5 of Set 9 | kahului
# Processing Record 6 of Set 9 | palafrugell
# Processing Record 7 of Set 9 | antalaha
# Processing Record 8 of Set 9 | uvalde
# Processing Record 9 of Set 9 | urusha
# Processing Record 10 of Set 9 | barabai
# Processing Record 11 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 12 of Set 9 | gorgan
# Processing Record 13 of Set 9 | aykhal
# Processing Record 14 of Set 9 | hithadhoo
# Processing Record 15 of Set 9 | mahebourg
# Processing Record 16 of Set 9 | stornoway
# Processing Record 17 of Set 9 | chuzhou
# Processing Record 18 of Set 9 | oistins
# Processing Record 19 of Set 9 | birnin kebbi
# Processing Record 20 of Set 9 | maunabo
# Processing Record 21 of Set 9 | qasigiannguit
# Processing Record 22 of Set 9 | pekalongan
# Processing Record 23 of Set 9 | talara
# Processing Record 24 of Set 9 | owando
# Processing Record 25 of Set 9 | crixas
# Processing Record 26 of Set 9 | buin
# Processing Record 27 of Set 9 | tezu
# Processing Record 28 of Set 9 | sibolga
# Processing Record 29 of Set 9 | sokolovo
# Processing Record 30 of Set 9 | lobito
# Processing Record 31 of Set 9 | calvinia
# Processing Record 32 of Set 9 | novikovo
# Processing Record 33 of Set 9 | kisarawe
# Processing Record 34 of Set 9 | bengkalis
# City not found. Skipping...
# Processing Record 35 of Set 9 | bad gandersheim
# Processing Record 36 of Set 9 | gambo
# Processing Record 37 of Set 9 | chara
# Processing Record 38 of Set 9 | youkounkoun
# Processing Record 39 of Set 9 | rio gallegos
# Processing Record 40 of Set 9 | sumbawa
# City not found. Skipping...
# Processing Record 41 of Set 9 | broome
# Processing Record 42 of Set 9 | baykit
# Processing Record 43 of Set 9 | makakilo city
# Processing Record 44 of Set 9 | juneau
# Processing Record 45 of Set 9 | mandiana
# Processing Record 46 of Set 9 | olafsvik
# Processing Record 47 of Set 9 | ostrovnoy
# Processing Record 48 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 49 of Set 9 | te anau
# Processing Record 50 of Set 9 | tierra colorada
# Processing Record 1 of Set 10 | dawlatabad
# Processing Record 2 of Set 10 | saint george
# Processing Record 3 of Set 10 | oranjemund
# Processing Record 4 of Set 10 | richards bay
# Processing Record 5 of Set 10 | gurgan
# City not found. Skipping...
# Processing Record 6 of Set 10 | faya
# Processing Record 7 of Set 10 | north bend
# Processing Record 8 of Set 10 | winneba
# Processing Record 9 of Set 10 | port macquarie
# Processing Record 10 of Set 10 | ketchikan
# Processing Record 11 of Set 10 | egvekinot
# Processing Record 12 of Set 10 | khotynets
# Processing Record 13 of Set 10 | santa cruz
# Processing Record 14 of Set 10 | tamandare
# Processing Record 15 of Set 10 | manono
# Processing Record 16 of Set 10 | almunecar
# Processing Record 17 of Set 10 | abay
# Processing Record 18 of Set 10 | floro
# Processing Record 19 of Set 10 | padang
# Processing Record 20 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 21 of Set 10 | jonkoping
# Processing Record 22 of Set 10 | mehran
# Processing Record 23 of Set 10 | khasan
# Processing Record 24 of Set 10 | zemio
# Processing Record 25 of Set 10 | storforshei
# Processing Record 26 of Set 10 | kumba
# Processing Record 27 of Set 10 | qurayyat
# Processing Record 28 of Set 10 | lensk
# Processing Record 29 of Set 10 | pevek
# Processing Record 30 of Set 10 | zadar
# Processing Record 31 of Set 10 | santa lucia
# Processing Record 32 of Set 10 | ixtapa
# Processing Record 33 of Set 10 | saint-pierre
# Processing Record 34 of Set 10 | mengcheng
# Processing Record 35 of Set 10 | oussouye
# Processing Record 36 of Set 10 | biak
# Processing Record 37 of Set 10 | la palma
# Processing Record 38 of Set 10 | liniere
# City not found. Skipping...
# Processing Record 39 of Set 10 | kargasok
# Processing Record 40 of Set 10 | westport
# Processing Record 41 of Set 10 | parabel
# Processing Record 42 of Set 10 | vostok
# Processing Record 43 of Set 10 | shache
# Processing Record 44 of Set 10 | tutoia
# Processing Record 45 of Set 10 | alibag
# Processing Record 46 of Set 10 | axim
# Processing Record 47 of Set 10 | nara
# Processing Record 48 of Set 10 | sorong
# Processing Record 49 of Set 10 | monster
# Processing Record 50 of Set 10 | paujiles
# Processing Record 1 of Set 11 | partizanskoye
# Processing Record 2 of Set 11 | port-gentil
# Processing Record 3 of Set 11 | avera
# Processing Record 4 of Set 11 | lodja
# Processing Record 5 of Set 11 | pyinmana
# Processing Record 6 of Set 11 | mineros
# Processing Record 7 of Set 11 | alugan
# Processing Record 8 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 9 of Set 11 | kutum
# Processing Record 10 of Set 11 | laiyang
# Processing Record 11 of Set 11 | thinadhoo
# Processing Record 12 of Set 11 | namibe
# Processing Record 13 of Set 11 | geraldton
# Processing Record 14 of Set 11 | taltal
# Processing Record 15 of Set 11 | taitung
# Processing Record 16 of Set 11 | dicabisagan
# Processing Record 17 of Set 11 | lapeer
# Processing Record 18 of Set 11 | bairiki
# Processing Record 19 of Set 11 | labuhan
# Processing Record 20 of Set 11 | sechura
# Processing Record 21 of Set 11 | uige
# Processing Record 22 of Set 11 | kununurra
# Processing Record 23 of Set 11 | rundu
# Processing Record 24 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 25 of Set 11 | grenada
# Processing Record 26 of Set 11 | canoinhas
# Processing Record 27 of Set 11 | alice springs
# Processing Record 28 of Set 11 | rocha
# Processing Record 29 of Set 11 | omsukchan
# Processing Record 30 of Set 11 | grand gaube
# Processing Record 31 of Set 11 | nuevitas
# Processing Record 32 of Set 11 | vao
# Processing Record 33 of Set 11 | catuday
# Processing Record 34 of Set 11 | port lincoln
# Processing Record 35 of Set 11 | veraval
# Processing Record 36 of Set 11 | weiswampach
# Processing Record 37 of Set 11 | magdagachi
# Processing Record 38 of Set 11 | abaete
# Processing Record 39 of Set 11 | mackenzie
# Processing Record 40 of Set 11 | dukat
# Processing Record 41 of Set 11 | chapais
# Processing Record 42 of Set 11 | tual
# Processing Record 43 of Set 11 | bang saphan
# Processing Record 44 of Set 11 | dunedin
# Processing Record 45 of Set 11 | terre-de-bas
# Processing Record 46 of Set 11 | camopi
# Processing Record 47 of Set 11 | aguas formosas
# Processing Record 48 of Set 11 | birobidzhan
# Processing Record 49 of Set 11 | paraguari
# Processing Record 50 of Set 11 | canton
# Processing Record 1 of Set 12 | digri
# Processing Record 2 of Set 12 | matara
# Processing Record 3 of Set 12 | santa ines
# Processing Record 4 of Set 12 | sisimiut
# Processing Record 5 of Set 12 | qui nhon
# Processing Record 6 of Set 12 | nome
# Processing Record 7 of Set 12 | tizimin
# Processing Record 8 of Set 12 | yefremov
# Processing Record 9 of Set 12 | erdenet
# Processing Record 10 of Set 12 | nanticoke
# Processing Record 11 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 12 of Set 12 | nuuk
# Processing Record 13 of Set 12 | chumikan
# Processing Record 14 of Set 12 | jiwani
# Processing Record 15 of Set 12 | tabas
# Processing Record 16 of Set 12 | soure
# Processing Record 17 of Set 12 | roseau
# Processing Record 18 of Set 12 | lamesa
# Processing Record 19 of Set 12 | margate
# Processing Record 20 of Set 12 | dulce nombre de culmi
# Processing Record 21 of Set 12 | khonsa
# Processing Record 22 of Set 12 | adre
# Processing Record 23 of Set 12 | klyuchi
# Processing Record 24 of Set 12 | kieta
# Processing Record 25 of Set 12 | cabo rojo
# Processing Record 26 of Set 12 | constantine
# Processing Record 27 of Set 12 | koumac
# Processing Record 28 of Set 12 | tomatlan
# Processing Record 29 of Set 12 | bargal
# City not found. Skipping...
# Processing Record 30 of Set 12 | burica
# City not found. Skipping...
# Processing Record 31 of Set 12 | cholet
# Processing Record 32 of Set 12 | karamay
# City not found. Skipping...
# Processing Record 33 of Set 12 | palmares
# Processing Record 34 of Set 12 | nsoko
# Processing Record 35 of Set 12 | katherine
# Processing Record 36 of Set 12 | sur
# Processing Record 37 of Set 12 | atasu
# Processing Record 38 of Set 12 | ergani
# Processing Record 39 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 40 of Set 12 | lopatyn
# Processing Record 41 of Set 12 | ambilobe
# Processing Record 42 of Set 12 | basco
# Processing Record 43 of Set 12 | dumas
# Processing Record 44 of Set 12 | fereydun kenar
# Processing Record 45 of Set 12 | whitianga
# Processing Record 46 of Set 12 | khilok
# Processing Record 47 of Set 12 | cam ranh
# Processing Record 48 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 12 | paita
# Processing Record 50 of Set 12 | peleduy
# Processing Record 1 of Set 13 | marivan
# Processing Record 2 of Set 13 | dois irmaos
# Processing Record 3 of Set 13 | meyungs
# City not found. Skipping...
# Processing Record 4 of Set 13 | eureka
# Processing Record 5 of Set 13 | challans
# Processing Record 6 of Set 13 | kotka
# Processing Record 7 of Set 13 | havre-saint-pierre
# Processing Record 8 of Set 13 | puerto madero
# Processing Record 9 of Set 13 | pizarro
# Processing Record 10 of Set 13 | onokhoy
# Processing Record 11 of Set 13 | boyolangu
# Processing Record 12 of Set 13 | kamariotissa
# Processing Record 13 of Set 13 | san cristobal
# Processing Record 14 of Set 13 | jiangyou
# Processing Record 15 of Set 13 | antsohihy
# Processing Record 16 of Set 13 | abashiri
# Processing Record 17 of Set 13 | deputatskiy
# Processing Record 18 of Set 13 | lupiro
# Processing Record 19 of Set 13 | chelno-vershiny
# Processing Record 20 of Set 13 | mednogorsk
# Processing Record 21 of Set 13 | phrai bung
# City not found. Skipping...
# Processing Record 22 of Set 13 | marzuq
# Processing Record 23 of Set 13 | hokitika
# Processing Record 24 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 25 of Set 13 | srandakan
# Processing Record 26 of Set 13 | villa carlos paz
# Processing Record 27 of Set 13 | teguldet
# Processing Record 28 of Set 13 | saint anthony
# Processing Record 29 of Set 13 | nusaybin
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
new_column_order = ["City",
                    "Country",
                    "Date",
                    "Lat",
                    "Lng",
                    "Max Temp",
                    "Humidity",
                    "Cloudiness",
                    "Wind Speed",
                    "Weather description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head()
# Out:
#          City Country                 Date      Lat       Lng  Max Temp  \
# 0       Bluff      NZ  2022-03-05 18:54:38 -46.6000  168.3333     64.80
# 1   Busselton      AU  2022-03-05 18:54:39 -33.6500  115.3333     66.04
# 2    Khatanga      RU  2022-03-05 18:54:39  71.9667  102.5000    -22.95
# 3         Leh      IN  2022-03-05 18:54:39  34.1667   77.5833      9.41
# 4  Bredasdorp      ZA  2022-03-05 18:54:40 -34.5322   20.0403     71.28
#
#    Humidity  Cloudiness  Wind Speed Weather description
# 0        71          93       14.85     overcast clouds
# 1        73           0       11.86           clear sky
# 2        99          99        7.20     overcast clouds
# 3        65          85        2.04     overcast clouds
# 4        73           0       13.80           clear sky

# %%
# Reorder thr DataFrame Columns
new_column_order = ["City", "Country", "Date", "Lat", "Lng","Max Temp", "Humidity", "Cloudiness", "Wind Speed","Weather description"]

# %%
# assign the same DataFrame with new column order:
# new_city_data_df = pd.DataFrame(city_data_df)
# new_city_data_df.head(10)

# %%
# new_city_data_df = new_city_data_df[new_column_order]
# new_city_data_df.head(10)

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# new_city_data_df.to_csv(output_data_file, index_label="City_ID")
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
